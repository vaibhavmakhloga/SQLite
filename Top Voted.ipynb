# %%
import sqlite3
import pandas as pd

# %%
connection=sqlite3.connect('Dataset/IMDB.sqlite')
dataset=pd.read_sql_query('select * from IMDB',connection)

# %%
copy=dataset.copy()

# %%
copy
# Out:
#     Movie_id                                              Title  Rating  \
# 0      36809                            12 Years a Slave (2013)     8.1
# 1      30114                                   127 Hours (2010)     7.6
# 2      37367                                       50/50 (2011)     7.7
# 3      49473                                  About Time (2013)     7.8
# 4      14867                                       Amour (2012)     7.9
# 5      33832                                        Argo (2012)     7.7
# 6      31722                                     Arrival (2016)     8.0
# 7      25398                             Before Midnight (2013)     7.9
# 8      10099                                  Big Hero 6 (2014)     7.8
# 9      25281  Birdman or (The Unexpected Virtue of Ignorance...     7.8
# 10     43358                                  Black Swan (2010)     8.0
# 11     36798                                     Boyhood (2014)     7.9
# ...

# %%
rate=copy['Rating']

# %%
maximum_rating=max(rate)
maximum_rating
# Out:
# 8.8

# %%
Top_rated_title=copy[copy['Rating']==max(rate)]
Top_rated_title
# Out:
#    Movie_id             Title  Rating  TotalVotes MetaCritic   Budget  \
# 45    46824  Inception (2010)     8.8     1609713         74  1.6e+08
#
#     Runtime CVotes10 CVotes09 CVotes08   ...    Votes3044 Votes3044M  \
# 45  148 min   584839   485218   304457   ...          8.7        8.7
#
#    Votes3044F Votes45A Votes45AM Votes45AF VotesIMDB Votes1000 VotesUS  \
# 45        8.5      8.1       8.1       8.0       8.6       8.2     8.7
#
#    VotesnUS
# 45      8.8
#
# [1 rows x 52 columns]

# %%
print(Top_rated_title['Title'])
print(Top_rated_title['Rating'])
# Out:
# 45    Inception (2010)
# Name: Title, dtype: object
# 45    8.8
# Name: Rating, dtype: float64
